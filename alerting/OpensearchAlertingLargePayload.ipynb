# %% [markdown]
# # Opensearch Alerting Traffic Generator

# %% [markdown]
# ## imports

# %%
# imports
from datetime import datetime
from faker import Faker
from random import randint
from opensearchpy import OpenSearch
import csv, random, time, os, base64

# %% [markdown]
# ## Setup

# %%
# objects
faker = Faker()

def generate_large_payload(size_in_mb=1):
    """
    Generate a base64-encoded string that consumes approximately `size_in_mb` of uncompressed space.
    The resulting string will be ~33% larger due to base64 encoding.
    """
    raw_bytes = os.urandom(size_in_mb * 1024 * 1024)  # 1MB of random bytes
    return base64.b64encode(raw_bytes).decode('utf-8')
    
# functions
def createRanNum():
    # return a standard log level
    # weighted on a sale of 0-100 so most should be info
    ranNumber = random.randint(0, 100)
    if ranNumber >= 0 and ranNumber <= 70:
        ranNumber = "1"
    elif ranNumber >= 71 and ranNumber <= 75:
        ranNumber = "2"
    elif ranNumber >= 76 and ranNumber <= 80:
        ranNumber = "3"
    elif ranNumber >= 81 and ranNumber <= 85:
        ranNumber = "4"
    elif ranNumber >= 86 and ranNumber <= 90:
        ranNumber = "5"
    elif ranNumber >= 91 and ranNumber <= 98:
        ranNumber = "6"   
    else:
        ranNumber = "9" #  + str(ranNumber)   
    return ranNumber

def createLogLevel():
    # return a standard log level
    # weighted on a sale of 0-100 so most should be info
    ranNumber = random.randint(0, 100)
    if ranNumber >= 0 and ranNumber <= 70:
        logLevel = "info"
    elif ranNumber >= 71 and ranNumber <= 75:
        logLevel = "debug"
    elif ranNumber >= 76 and ranNumber <= 80:
        logLevel = "trace"
    elif ranNumber >= 81 and ranNumber <= 85:
        logLevel = "warn"
    elif ranNumber >= 86 and ranNumber <= 90:
        logLevel = "error"
    elif ranNumber >= 91 and ranNumber <= 99:
        logLevel = "critical"    
    else:
        logLevel = "fatal " #  + str(ranNumber)    
    return logLevel

def get_random_item(list_name, random_range):
    '''
    return a random item from a list
    '''
    ran = random.randint(1,random_range)
    return list_name[ran]

def createHttpResponseCode():
    # return response code
    # weighted on a sale of 0-100
    # 200's/300's should be most common
    ranNumber = random.randint(0, 100)
    if ranNumber >= 0 and ranNumber <= 90:
        httpResponse = "1"  # 100/200/300 not important
    elif ranNumber >= 91 and ranNumber <= 97:
        httpResponse = "3"  #400's 
    else:
        httpResponse = "6" # 500   
    return httpResponse

def read_csv(csvFilename, row_number):
    '''
    read a CSV file into a list
    args are filename and row of the desired item
    '''
    with open(csvFilename) as f:
        # list object to return
        return_list = []
        # open the file which returns a pointer to the 1st line
        reader = csv.reader(f)
        # this will move the pointer to the next line so it skips the header line of the CSV
        next(reader)
        for row in reader:
            # print it if you want
            # print(row[row_number])
            # add it to a list
            return_list.append(row[row_number])
    return return_list

# %% [markdown]
# ## Send test data to OpenSearch

# %%
if __name__ == '__main__':
    # variables
    host = [{'host': '127.0.0.1', 'port': 9200}]
    # auth = ('index_writer_user', 'IndexWriter123!')
    auth = ('admin', 'Opensearch123!')
    # ca_certs_path = '/home/bikeride/opensearch/opensearch-2.3.0/config/root-ca.pem'
    # target_index = 'test_index1'
    target_index = 'logs-index_alert_storage'
    # client = OpenSearch(hosts=host,http_compress=True,http_auth=auth,use_ssl=True,verify_certs=True,ssl_assert_hostname=False,ssl_show_warn=False,ca_certs=ca_certs_path)
    client = OpenSearch(
        hosts=host,
        http_compress=True,
        http_auth=auth,
        use_ssl=True,
        verify_certs=False,
        ssl_assert_hostname=False,
        ssl_show_warn=False
    )
    
    # generate lists from CSV files
    humanReadableCsv = "/home/bikeride/Documents/csvFiles/Human-to-HumanActionableRequestsDataset.csv"
    messageList = read_csv(humanReadableCsv, 1)
    msgTypeList = read_csv(humanReadableCsv, 0)
    msgDirectionList = read_csv(humanReadableCsv, 2)
    msgValidtyList = read_csv(humanReadableCsv, 3)
    #
    # set up to run for timed run in seconds
    runTime = 600
    timeToRun = int(time.time() + runTime)
    # for i in range(1000):
    while (int(time.time()) < int(timeToRun)):
        payload = generate_large_payload(size_in_mb=1)
        severity = createRanNum()
        loglevel = createLogLevel()
        http_response_code = createHttpResponseCode()
        message = get_random_item(messageList, len(messageList) -1)
        msgType =  get_random_item(msgTypeList, len(msgTypeList) -1)
        msgDirection =  get_random_item(msgDirectionList, len(msgDirectionList) -1)
        msgValidity = get_random_item(msgValidtyList, len(msgValidtyList) -1)
        return_status = faker.boolean()
        hostname = faker.hostname()
        # get a timestamp
        today = datetime.now().astimezone()
        iso_datetime = today.isoformat()
        # set up the event
        document = {
            '@timestamp' : iso_datetime,
            'msg': message,
            'msg_type': msgType,
            'msg_direction': msgDirection,
            #'msg_validity': msgValidity,
            'severity': severity,
            'return_status': return_status,
            'http_response_code': http_response_code,
            'log_level': loglevel,
            'hostname': hostname,
            'large_payload': payload
            }
        # send a write request
        response = client.index(
            index = target_index,
            body = document,
            refresh = True
            )
        # print the response if you want
        print(response)
        # short random delay
        time.sleep((random.random()))
# Out:
# {'_index': 'logs-index_alert_storage', '_id': '4xXzMJYBxYAHncrUHBWi', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '5BXzMJYBxYAHncrUIxUp', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '5RXzMJYBxYAHncrUKBUt', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '5hXzMJYBxYAHncrULhXx', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '5xXzMJYBxYAHncrUMxUq', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '6BXzMJYBxYAHncrUORWr', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '6RXzMJYBxYAHncrUQBVg', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '6hXzMJYBxYAHncrURxV2', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '6xXzMJYBxYAHncrUThVs', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '7BXzMJYBxYAHncrUUhXZ', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '7RXzMJYBxYAHncrUVxXi', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '8BXzMJYBxYAHncrUXBXq', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '8xXzMJYBxYAHncrUYxXT', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '9BXzMJYBxYAHncrUaxWR', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '9RXzMJYBxYAHncrUchUp', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '9hXzMJYBxYAHncrUdhWG', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '9xXzMJYBxYAHncrUfBXl', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '-RXzMJYBxYAHncrUgRWx', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '-hXzMJYBxYAHncrUhhWd', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '-xXzMJYBxYAHncrUihVD', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '_BXzMJYBxYAHncrUkBUm', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '_RXzMJYBxYAHncrUlRUX', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '_hXzMJYBxYAHncrUmhVh', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': '_xXzMJYBxYAHncrUnxUz', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'ABXzMJYBxYAHncrUpBZQ', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'ARXzMJYBxYAHncrUqxZd', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'AhXzMJYBxYAHncrUsBZc', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'AxXzMJYBxYAHncrUsxbf', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'BBXzMJYBxYAHncrUuhZt', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'BRXzMJYBxYAHncrUvhZJ', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'BhXzMJYBxYAHncrUxhZv', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'BxXzMJYBxYAHncrUzRaG', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'CBXzMJYBxYAHncrU0xZ-', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# {'_index': 'logs-index_alert_storage', '_id': 'CRXzMJYBxYAHncrU2RaC', '_version': 1, 'result': 'created', 'forced_refresh': True, '_shards': {'total': 2, 'successful': 2, 'failed': 0}, '_seq_no':